# %%
# !pip install numpy==2.0.2
# !pip install pandas==2.2.2
# !pip install tensorflow_cpu==2.18.0
# !pip install matplotlib==3.9.2
# !pip install --upgrade ml_dtypes jax jaxlib
# Out:
# Requirement already satisfied: numpy==2.0.2 in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: pandas==2.2.2 in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas==2.2.2) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas==2.2.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas==2.2.2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas==2.2.2) (2026.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas==2.2.2) (1.17.0)
# Requirement already satisfied: tensorflow_cpu==2.18.0 in /usr/local/lib/python3.12/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.18.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.18.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.18.0) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.18.0) (0.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.18.0) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.18.0) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.18.0) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.18.0) (26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.18.0) (5.29.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.18.0) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.18.0) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.18.0) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.18.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.18.0) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.18.0) (2.1.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.18.0) (1.80.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.18.0) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.18.0) (3.13.2)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.18.0) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.18.0) (3.16.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow_cpu==2.18.0) (0.4.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow_cpu==2.18.0) (0.47.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow_cpu==2.18.0) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow_cpu==2.18.0) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow_cpu==2.18.0) (0.19.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow_cpu==2.18.0) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow_cpu==2.18.0) (3.13)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow_cpu==2.18.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow_cpu==2.18.0) (2026.4.22)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard<2.19,>=2.18->tensorflow_cpu==2.18.0) (3.10.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard<2.19,>=2.18->tensorflow_cpu==2.18.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard<2.19,>=2.18->tensorflow_cpu==2.18.0) (3.1.8)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow_cpu==2.18.0) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow_cpu==2.18.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow_cpu==2.18.0) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow_cpu==2.18.0) (0.1.2)
# Requirement already satisfied: matplotlib==3.9.2 in /usr/local/lib/python3.12/dist-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.2) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.2) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.2) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.2) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.2) (26.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.2) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.2) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.2) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib==3.9.2) (1.17.0)
# Requirement already satisfied: ml_dtypes in /usr/local/lib/python3.12/dist-packages (0.4.1)
# Collecting ml_dtypes
#   Downloading ml_dtypes-0.5.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.9 kB)
# Requirement already satisfied: jax in /usr/local/lib/python3.12/dist-packages (0.7.2)
# Collecting jax
#   Downloading jax-0.10.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.12/dist-packages (0.7.2)
# Collecting jaxlib
#   Downloading jaxlib-0.10.0-cp312-cp312-manylinux_2_27_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.12/dist-packages (from ml_dtypes) (2.0.2)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.12/dist-packages (from jax) (3.4.0)
# Requirement already satisfied: scipy>=1.14 in /usr/local/lib/python3.12/dist-packages (from jax) (1.16.3)
# Downloading ml_dtypes-0.5.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 49.8 MB/s eta 0:00:00
# Downloading jax-0.10.0-py3-none-any.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 79.8 MB/s eta 0:00:00
# Downloading jaxlib-0.10.0-cp312-cp312-manylinux_2_27_x86_64.whl (85.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 MB 5.5 MB/s eta 0:00:00
# Installing collected packages: ml_dtypes, jaxlib, jax
#   Attempting uninstall: ml_dtypes
#     Found existing installation: ml-dtypes 0.4.1
#     Uninstalling ml-dtypes-0.4.1:
#       Successfully uninstalled ml-dtypes-0.4.1
#   Attempting uninstall: jaxlib
#     Found existing installation: jaxlib 0.7.2
#     Uninstalling jaxlib-0.7.2:
#       Successfully uninstalled jaxlib-0.7.2
#   Attempting uninstall: jax
#     Found existing installation: jax 0.7.2
#     Uninstalling jax-0.7.2:
#       Successfully uninstalled jax-0.7.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-cpu 2.18.0 requires ml-dtypes<0.5.0,>=0.4.0, but you have ml-dtypes 0.5.4 which is incompatible.
# tensorflow 2.20.0 requires tensorboard~=2.20.0, but you have tensorboard 2.18.0 which is incompatible.
# Successfully installed jax-0.10.0 jaxlib-0.10.0 ml_dtypes-0.5.4

# %%
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten
from keras.utils import to_categorical

# %% [markdown]
# ##Convolutional Neural Network with One Set of Convolutional and Pooling Layers

# %%
from keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()

X_train = X_train.reshape(-1, 28, 28, 1).astype('float32')
X_test = X_test.reshape(-1, 28, 28, 1).astype('float32')

X_train /= 255
X_test /= 255
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

num_classes = y_test.shape[1] # number of categories

# %%
def convolutional_model():
  model = Sequential()
  model.add(Input(shape=(28, 28, 1)))
  model.add(Conv2D(16, (5, 5), strides=(1,1), activation='relu'))
  model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

  model.add(Flatten())
  model.add(Dense(100, activation='relu'))
  model.add(Dense(num_classes, activation='softmax'))

  model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
  return model

# %%
model = convolutional_model()

model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=2)

scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/10
# 300/300 - 24s - 81ms/step - accuracy: 0.9119 - loss: 0.3099 - val_accuracy: 0.9678 - val_loss: 0.1145
# Epoch 2/10
# 300/300 - 40s - 133ms/step - accuracy: 0.9739 - loss: 0.0906 - val_accuracy: 0.9815 - val_loss: 0.0637
# Epoch 3/10
# 300/300 - 22s - 73ms/step - accuracy: 0.9818 - loss: 0.0603 - val_accuracy: 0.9839 - val_loss: 0.0489
# Epoch 4/10
# 300/300 - 41s - 136ms/step - accuracy: 0.9858 - loss: 0.0477 - val_accuracy: 0.9857 - val_loss: 0.0443
# Epoch 5/10
# 300/300 - 22s - 72ms/step - accuracy: 0.9887 - loss: 0.0387 - val_accuracy: 0.9845 - val_loss: 0.0447
# Epoch 6/10
# 300/300 - 41s - 137ms/step - accuracy: 0.9900 - loss: 0.0322 - val_accuracy: 0.9875 - val_loss: 0.0373
# Epoch 7/10
# 300/300 - 40s - 133ms/step - accuracy: 0.9913 - loss: 0.0285 - val_accuracy: 0.9871 - val_loss: 0.0368
# Epoch 8/10
# 300/300 - 22s - 72ms/step - accuracy: 0.9929 - loss: 0.0242 - val_accuracy: 0.9875 - val_loss: 0.0371
# Epoch 9/10
# 300/300 - 22s - 72ms/step - accuracy: 0.9940 - loss: 0.0199 - val_accuracy: 0.9873 - val_loss: 0.0380
# Epoch 10/10
# 300/300 - 21s - 70ms/step - accuracy: 0.9948 - loss: 0.0170 - val_accuracy: 0.9858 - val_loss: 0.0446
# Accuracy: 0.98580002784729
#  Error: 1.419997215270996

# %% [markdown]
# ##Convolutional Neural Network with Two Sets of Convolutional and Pooling Layers

# %%
def convolutional_model2():

    # create model
    model = Sequential()
    model.add(Input(shape=(28, 28, 1)))
    model.add(Conv2D(16, (5, 5), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

    model.add(Conv2D(8, (2, 2), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))

    model.add(Flatten())
    model.add(Dense(100, activation='relu'))
    model.add(Dense(num_classes, activation='softmax'))

    # Compile model
    model.compile(optimizer='adam', loss='categorical_crossentropy',  metrics=['accuracy'])
    return model

# %%
# build the model
model = convolutional_model()

# fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=200, verbose=2)

# evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/10
# 300/300 - 23s - 78ms/step - accuracy: 0.9146 - loss: 0.3063 - val_accuracy: 0.9676 - val_loss: 0.1118
# Epoch 2/10
# 300/300 - 21s - 69ms/step - accuracy: 0.9740 - loss: 0.0922 - val_accuracy: 0.9794 - val_loss: 0.0650
# Epoch 3/10
# 300/300 - 22s - 73ms/step - accuracy: 0.9825 - loss: 0.0596 - val_accuracy: 0.9831 - val_loss: 0.0505
# Epoch 4/10
# 300/300 - 39s - 132ms/step - accuracy: 0.9875 - loss: 0.0445 - val_accuracy: 0.9840 - val_loss: 0.0476
# Epoch 5/10
# 300/300 - 22s - 73ms/step - accuracy: 0.9892 - loss: 0.0364 - val_accuracy: 0.9857 - val_loss: 0.0420
# Epoch 6/10
# 300/300 - 22s - 73ms/step - accuracy: 0.9908 - loss: 0.0301 - val_accuracy: 0.9871 - val_loss: 0.0390
# Epoch 7/10
# 300/300 - 41s - 136ms/step - accuracy: 0.9922 - loss: 0.0249 - val_accuracy: 0.9877 - val_loss: 0.0400
# Epoch 8/10
# 300/300 - 40s - 133ms/step - accuracy: 0.9935 - loss: 0.0216 - val_accuracy: 0.9861 - val_loss: 0.0404
# Epoch 9/10
# 300/300 - 22s - 72ms/step - accuracy: 0.9954 - loss: 0.0159 - val_accuracy: 0.9851 - val_loss: 0.0442
# Epoch 10/10
# 300/300 - 22s - 72ms/step - accuracy: 0.9956 - loss: 0.0149 - val_accuracy: 0.9882 - val_loss: 0.0371
# Accuracy: 0.9882000088691711
#  Error: 1.1799991130828857

# %% [markdown]
# Let's see how batch size affects the time required and accuracy of the model training.
# For this, you can try to change batch_size to 1024 and check it's effect on accuracy

# %%
# build the model
model = convolutional_model()

# fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=10, batch_size=1024, verbose=2)

# evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/10
# 59/59 - 24s - 399ms/step - accuracy: 0.8418 - loss: 0.6415 - val_accuracy: 0.9408 - val_loss: 0.2138
# Epoch 2/10
# 59/59 - 39s - 666ms/step - accuracy: 0.9500 - loss: 0.1719 - val_accuracy: 0.9646 - val_loss: 0.1238
# Epoch 3/10
# 59/59 - 22s - 371ms/step - accuracy: 0.9685 - loss: 0.1120 - val_accuracy: 0.9728 - val_loss: 0.0894
# Epoch 4/10
# 59/59 - 21s - 353ms/step - accuracy: 0.9762 - loss: 0.0840 - val_accuracy: 0.9784 - val_loss: 0.0682
# Epoch 5/10
# 59/59 - 21s - 358ms/step - accuracy: 0.9805 - loss: 0.0677 - val_accuracy: 0.9818 - val_loss: 0.0578
# Epoch 6/10
# 59/59 - 40s - 684ms/step - accuracy: 0.9844 - loss: 0.0565 - val_accuracy: 0.9829 - val_loss: 0.0511
# Epoch 7/10
# 59/59 - 21s - 360ms/step - accuracy: 0.9856 - loss: 0.0497 - val_accuracy: 0.9829 - val_loss: 0.0496
# Epoch 8/10
# 59/59 - 22s - 380ms/step - accuracy: 0.9869 - loss: 0.0450 - val_accuracy: 0.9818 - val_loss: 0.0532
# Epoch 9/10
# 59/59 - 21s - 349ms/step - accuracy: 0.9878 - loss: 0.0410 - val_accuracy: 0.9852 - val_loss: 0.0427
# Epoch 10/10
# 59/59 - 22s - 372ms/step - accuracy: 0.9901 - loss: 0.0351 - val_accuracy: 0.9854 - val_loss: 0.0420
# Accuracy: 0.9854000210762024
#  Error: 1.4599978923797607

# %% [markdown]
# Now, let's see how number of epochs affect the time required and accuracy of the model training. For this, you can keep the batch_size=1024 and epochs=25 and check it's effect on accuracy

# %%
# build the model
model = convolutional_model()

# fit the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=25, batch_size=1024, verbose=2)

# evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
print("Accuracy: {} \n Error: {}".format(scores[1], 100-scores[1]*100))
# Out:
# Epoch 1/25
# 59/59 - 24s - 407ms/step - accuracy: 0.8364 - loss: 0.6342 - val_accuracy: 0.9281 - val_loss: 0.2554
# Epoch 2/25
# 59/59 - 22s - 369ms/step - accuracy: 0.9363 - loss: 0.2229 - val_accuracy: 0.9510 - val_loss: 0.1760
# Epoch 3/25
# 59/59 - 20s - 347ms/step - accuracy: 0.9578 - loss: 0.1508 - val_accuracy: 0.9646 - val_loss: 0.1230
# Epoch 4/25
# 59/59 - 22s - 370ms/step - accuracy: 0.9690 - loss: 0.1110 - val_accuracy: 0.9728 - val_loss: 0.0949
# Epoch 5/25
# 59/59 - 39s - 668ms/step - accuracy: 0.9758 - loss: 0.0867 - val_accuracy: 0.9770 - val_loss: 0.0773
# Epoch 6/25
# 59/59 - 22s - 368ms/step - accuracy: 0.9793 - loss: 0.0733 - val_accuracy: 0.9803 - val_loss: 0.0665
# Epoch 7/25
# 59/59 - 40s - 672ms/step - accuracy: 0.9828 - loss: 0.0615 - val_accuracy: 0.9805 - val_loss: 0.0606
# Epoch 8/25
# 59/59 - 21s - 361ms/step - accuracy: 0.9852 - loss: 0.0533 - val_accuracy: 0.9828 - val_loss: 0.0577
# Epoch 9/25
# 59/59 - 42s - 704ms/step - accuracy: 0.9862 - loss: 0.0487 - val_accuracy: 0.9837 - val_loss: 0.0493
# Epoch 10/25
# 59/59 - 40s - 670ms/step - accuracy: 0.9880 - loss: 0.0428 - val_accuracy: 0.9848 - val_loss: 0.0488
# Epoch 11/25
# 59/59 - 21s - 361ms/step - accuracy: 0.9881 - loss: 0.0413 - val_accuracy: 0.9857 - val_loss: 0.0451
# Epoch 12/25
# 59/59 - 40s - 672ms/step - accuracy: 0.9900 - loss: 0.0353 - val_accuracy: 0.9856 - val_loss: 0.0443
# Epoch 13/25
# 59/59 - 22s - 367ms/step - accuracy: 0.9909 - loss: 0.0329 - val_accuracy: 0.9833 - val_loss: 0.0504
# Epoch 14/25
# 59/59 - 21s - 352ms/step - accuracy: 0.9918 - loss: 0.0300 - val_accuracy: 0.9866 - val_loss: 0.0415
# Epoch 15/25
# 59/59 - 42s - 710ms/step - accuracy: 0.9922 - loss: 0.0279 - val_accuracy: 0.9865 - val_loss: 0.0405
# Epoch 16/25
# 59/59 - 20s - 345ms/step - accuracy: 0.9927 - loss: 0.0265 - val_accuracy: 0.9862 - val_loss: 0.0411
# Epoch 17/25
# 59/59 - 21s - 359ms/step - accuracy: 0.9937 - loss: 0.0235 - val_accuracy: 0.9870 - val_loss: 0.0387
# Epoch 18/25
# 59/59 - 22s - 367ms/step - accuracy: 0.9940 - loss: 0.0222 - val_accuracy: 0.9870 - val_loss: 0.0396
# Epoch 19/25
# 59/59 - 41s - 688ms/step - accuracy: 0.9943 - loss: 0.0203 - val_accuracy: 0.9870 - val_loss: 0.0401
# Epoch 20/25
# 59/59 - 21s - 360ms/step - accuracy: 0.9943 - loss: 0.0197 - val_accuracy: 0.9870 - val_loss: 0.0395
# Epoch 21/25
# 59/59 - 41s - 701ms/step - accuracy: 0.9951 - loss: 0.0177 - val_accuracy: 0.9864 - val_loss: 0.0418
# Epoch 22/25
# 59/59 - 22s - 370ms/step - accuracy: 0.9952 - loss: 0.0168 - val_accuracy: 0.9859 - val_loss: 0.0427
# Epoch 23/25
# 59/59 - 20s - 345ms/step - accuracy: 0.9959 - loss: 0.0156 - val_accuracy: 0.9876 - val_loss: 0.0375
# Epoch 24/25
# 59/59 - 22s - 365ms/step - accuracy: 0.9963 - loss: 0.0144 - val_accuracy: 0.9883 - val_loss: 0.0375
# Epoch 25/25
# 59/59 - 20s - 343ms/step - accuracy: 0.9969 - loss: 0.0130 - val_accuracy: 0.9877 - val_loss: 0.0390
# Accuracy: 0.9876999855041504
#  Error: 1.230001449584961
