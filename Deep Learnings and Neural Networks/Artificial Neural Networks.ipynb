# %% [markdown]
# **Artificial Neural Networks - Forward Propagation**

# %% [markdown]
# Objective for this Notebook
#  - Build a Neural Network
#  - Compute Weighted Sum at Each Node
#  - Compute Node Activation
#  - Use Forward Propagation to Propagate Data

# %%
# !pip install numpy
# Out:
# mambajs 0.19.13
#
# Process pip requirements ...
#
# Requirement numpy already handled by conda/micromamba/mamba.

# %%
import numpy as np

weights = np.around(np.random.uniform(size=6), decimals=2) #initialize weights
biases = np.around(np.random.uniform(size=3), decimals=2) #initialize biases

# %%
print(weights)
print(biases)
# Out:
# [0.83 0.27 0.17 0.53 0.24 0.46]
# [0.12 0.6  0.84]

# %%
x_1 = 0.5 # input 1
x_2 = 0.85 # input 2

print('x1 is {} and x2 is {}'.format(x_1, x_2))
# Out:
# x1 is 0.5 and x2 is 0.85

# %%
z_11 = x_1 * weights[0] + x_2 * weights[1] + biases[0]

print('The weighted sum of the inputs at the first node in the hidden layer is {}'.format(z_11))
# Out:
# The weighted sum of the inputs at the first node in the hidden layer is 0.7645

# %%
z_12 = x_1 * weights[2] + x_2 * weights[3] + biases[1]

print('The weighted sum of the inputs at the second node in the hidden layer is {}'.format(z_12))
# Out:
# The weighted sum of the inputs at the second node in the hidden layer is 1.1355

# %%
a_11 = 1.0 / (1.0 + np.exp(-z_11))

print('The activation of the first node in the hidden layer is {}'.format(np.around(a_11, decimals=4)))
# Out:
# The activation of the first node in the hidden layer is 0.6823

# %%
a_12 = 1.0 / (1.0 + np.exp(-z_12))

print('The activation of the second node in the hidden layer is {}'.format(np.around(a_12, decimals=4)))
# Out:
# The activation of the second node in the hidden layer is 0.7569

# %%
z_2 = a_11 * weights[4] + a_12 * weights[5] + biases[2]

print('The weighted sum of the inputs at the node in the output layer is {}'.format(np.around(z_2, decimals=4)))
# Out:
# The weighted sum of the inputs at the node in the output layer is 1.3519

# %%
a_2 = 1.0 / (1.0 + np.exp(-z_2))

print('The output of the network for x1 = 0.5 and x2 = 0.85 is {}'.format(np.around(a_2, decimals=4)))
# Out:
# The output of the network for x1 = 0.5 and x2 = 0.85 is 0.7944

# %% [markdown]
# **Build a Neural Network**

# %%
n = 2 # number of inputs
num_hidden_layers = 2 # number of hidden layers
m = [2, 2] # number of nodes in each hidden layer
num_nodes_output = 1 # number of nodes in the output layer

# %%
def initialize_network(num_inputs, num_hidden_layers, num_nodes_hidden, num_nodes_output):
    
    num_nodes_previous = num_inputs # number of nodes in the previous layer

    network = {}
    
    # loop through each layer and randomly initialize the weights and biases associated with each layer
    for layer in range(num_hidden_layers + 1):
        
        if layer == num_hidden_layers:
            layer_name = 'output' # name last layer in the network output
            num_nodes = num_nodes_output
        else:
            layer_name = 'layer_{}'.format(layer + 1) # otherwise give the layer a number
            num_nodes = num_nodes_hidden[layer] 
        
        # initialize weights and bias for each node
        network[layer_name] = {}
        for node in range(num_nodes):
            node_name = 'node_{}'.format(node+1)
            network[layer_name][node_name] = {
                'weights': np.around(np.random.uniform(size=num_nodes_previous), decimals=2),
                'bias': np.around(np.random.uniform(size=1), decimals=2),
            }
    
        num_nodes_previous = num_nodes

    return network # return the network

# %%
small_network = initialize_network(5, 3, [3, 2, 3], 1)
small_network
# Out:
# {'layer_1': {'node_1': {'weights': array([0.91, 0.95, 0.58, 0.51, 0.78]),
#    'bias': array([0.67])},
#   'node_2': {'weights': array([0.16, 0.43, 0.15, 0.57, 0.51]),
#    'bias': array([0.45])},
#   'node_3': {'weights': array([0.99, 0.9 , 0.15, 0.61, 0.48]),
#    'bias': array([0.83])}},
#  'layer_2': {'node_1': {'weights': array([0.93, 0.83, 0.03]),
#    'bias': array([0.89])},
#   'node_2': {'weights': array([0.16, 0.33, 0.38]), 'bias': array([0.82])}},
#  'layer_3': {'node_1': {'weights': array([0.2 , 0.18]), 'bias': array([0.99])},
#   'node_2': {'weights': array([0.04, 0.31]), 'bias': array([0.41])},
#   'node_3': {'weights': array([0.23, 0.27]), 'bias': array([0.11])}},
#  'output': {'node_1': {'weights': array([0.81, 0.25, 0.63]),
#    'bias': array([0.36])}}}

# %%
def compute_weighted_sum(inputs, weights, bias):
    return np.sum(inputs * weights) + bias

# %%
from random import seed

np.random.seed(12)
inputs = np.around(np.random.uniform(size=5), decimals=2)

print('The inputs to the network are {}'.format(inputs))
# Out:
# The inputs to the network are [0.15 0.74 0.26 0.53 0.01]

# %%
node_weights = small_network['layer_1']['node_1']['weights']
node_bias = small_network['layer_1']['node_1']['bias']

weighted_sum = compute_weighted_sum(inputs, node_weights, node_bias)

print('The weighted sum at the first node in the hidden layer is {}' .format(np.around(weighted_sum[0], decimals=4)))
# Out:
# The weighted sum at the first node in the hidden layer is 1.9384

# %%
def node_activation(weighted_sum):
    return 1.0 / (1.0 + np.exp(-1 * weighted_sum))

# %%
node_output = node_activation(weighted_sum)

print('The node output is {}' .format(np.around(node_output, decimals=4)))
# Out:
# The node output is [0.8742]

# %%
def forward_propagate(network, inputs):
    
    layer_inputs = list(inputs) # start with the input layer as the input to the first hidden layer
    
    for layer in network:
        
        layer_data = network[layer]
        
        layer_outputs = [] 
        for layer_node in layer_data:
        
            node_data = layer_data[layer_node]
        
            # compute the weighted sum and the output of each node at the same time 
            node_output = node_activation(compute_weighted_sum(layer_inputs, node_data['weights'], node_data['bias']))
            layer_outputs.append(np.around(node_output[0], decimals=4))
            
        if layer != 'output':
            print('The outputs of the nodes in hidden layer number {} is {}'.format(layer.split('_')[1], layer_outputs))
    
        layer_inputs = layer_outputs # set the output of this layer to be the input to next layer

    network_predictions = layer_outputs
    return network_predictions

# %%
predictions = forward_propagate(small_network, inputs)
print('The predicted value by the network for the given input is {}'.format(np.around(predictions[0], decimals=4)))
# Out:
# The outputs of the nodes in hidden layer number 1 is [np.float64(0.8742), np.float64(0.7574), np.float64(0.882)]
# The outputs of the nodes in hidden layer number 2 is [np.float64(0.9136), np.float64(0.8242)]
# The outputs of the nodes in hidden layer number 3 is [np.float64(0.7894), np.float64(0.6686), np.float64(0.6324)]
# The predicted value by the network for the given input is 0.8271

# %%
my_network = initialize_network(5, 3, [2, 3, 2], 3)

# %%
inputs = np.around(np.random.uniform(size=5), decimals=2)

# %%
predictions = forward_propagate(my_network, inputs)
print('The predicted values by the network for the given input are {}'.format(predictions))
# Out:
# The outputs of the nodes in hidden layer number 1 is [np.float64(0.8857), np.float64(0.8889)]
# The outputs of the nodes in hidden layer number 2 is [np.float64(0.7822), np.float64(0.6965), np.float64(0.7411)]
# The outputs of the nodes in hidden layer number 3 is [np.float64(0.868), np.float64(0.881)]
# The predicted values by the network for the given input are [np.float64(0.8952), np.float64(0.8222), np.float64(0.8035)]

# %%
my_network1 = initialize_network(10, 7, [4, 5, 2, 5, 3, 6, 8], 5)

# %%
inputs = np.around(np.random.uniform(size=10), decimals=2)

# %%
predictions = forward_propagate(my_network1, inputs)
print('The predicted values by the network for the given input are {}'.format(predictions))
# Out:
# The outputs of the nodes in hidden layer number 1 is [np.float64(0.7917), np.float64(0.9232), np.float64(0.8805), np.float64(0.944)]
# The outputs of the nodes in hidden layer number 2 is [np.float64(0.9549), np.float64(0.9063), np.float64(0.8981), np.float64(0.8629), np.float64(0.9155)]
# The outputs of the nodes in hidden layer number 3 is [np.float64(0.9219), np.float64(0.8942)]
# The outputs of the nodes in hidden layer number 4 is [np.float64(0.7757), np.float64(0.6915), np.float64(0.6498), np.float64(0.7908), np.float64(0.8564)]
# The outputs of the nodes in hidden layer number 5 is [np.float64(0.9047), np.float64(0.9235), np.float64(0.9316)]
# The outputs of the nodes in hidden layer number 6 is [np.float64(0.9013), np.float64(0.8017), np.float64(0.7934), np.float64(0.9518), np.float64(0.9404), np.float64(0.8543)]
# The outputs of the nodes in hidden layer number 7 is [np.float64(0.9794), np.float64(0.9881), np.float64(0.9513), np.float64(0.8966), np.float64(0.9639), np.float64(0.9501), np.float64(0.9596), np.float64(0.8989)]
# The predicted values by the network for the given input are [np.float64(0.9732), np.float64(0.9547), np.float64(0.9412), np.float64(0.9912), np.float64(0.9911)]
